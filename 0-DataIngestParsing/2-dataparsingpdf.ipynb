# %% [markdown]
# ### Load Pdf Files

# %%
from langchain_community.document_loaders import (
    PyPDFLoader,
    PyMuPDFLoader,
    UnstructuredPDFLoader)

# %%
#PypdfLoader Most common and used for loading pdf
print("PyPdfloader")

try:
    pypdf_loader=PyPDFLoader("data/pdf/attention.pdf")
    pypdf_loader.load()
except Exception as e:
    print(f"Error : {e}")
